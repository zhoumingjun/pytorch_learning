# %% [markdown]
# # This is the pytorch version of karpathy's charnn
#     reference: https://gist.github.com/raphaelbastide/11ae4bb5e454e5c5239f

# %%
import torch
from torch import nn
from torch.autograd import Variable
import torch.optim as optim

# %%
# data I/O
data = open('input.txt', 'r').read() # should be simple plain text file
chars = list(set(data))
data_size, vocab_size = len(data), len(chars)
print ('data has {} characters, {} unique.'.format( data_size, vocab_size))
char_to_ix = { ch:i for i,ch in enumerate(chars) }
ix_to_char = { i:ch for i,ch in enumerate(chars) }
# Out:
# data has 1570 characters, 49 unique.

# %%
# hyperparameters
hidden_size = 100 # size of hidden layer of neurons
seq_length = 25 # number of steps to unroll the RNN for
learning_rate = 1e-3

# %%
# Utility functions
def ix_to_tensor(ix):
    t = torch.FloatTensor(1, vocab_size).zero_()
    t[0][ix] = 1.0
    return Variable(t)

def tensor_to_ix(t):
    v,i = torch.max(t,1)
    return i.data[0][0]

# %%
# nn module
class CharRNN(nn.Module):
 
    def __init__(self, input_size, hidden_size, output_size):
        super(CharRNN, self).__init__()
        self.input_size = input_size
        self.hidden_size = hidden_size
        self.output_size = output_size
        
        self.rnn = nn.LSTMCell(input_size, hidden_size)
        self.linear = nn.Linear(hidden_size, output_size)
        
    def forward(self, input, h,c):
        h,c = self.rnn(input, (h,c))
        output = self.linear(h)
        return output, h,c

    def init_hidden(self):
        return Variable(torch.FloatTensor(1, self.hidden_size).zero_()) ,Variable(torch.FloatTensor(1, self.hidden_size).zero_())

# %%
rnn = CharRNN(vocab_size, hidden_size,vocab_size )
criterion=nn.CrossEntropyLoss()
optimizer = optim.Adam(rnn.parameters(), lr=learning_rate)

def train(inputs, targets, h,c):
    optimizer.zero_grad()

    loss = 0
    for i in range(len(inputs)):
        input = ix_to_tensor(inputs[i])
        target = Variable(torch.LongTensor([targets[i]]))

        output, h,c = rnn(input, h,c)
        loss += criterion(output, target)
    
    loss.backward()
    optimizer.step()

    return loss.data[0] , h,c

def sample(seed_ix, n):
    h,c = rnn.init_hidden()

    x = ix_to_tensor(seed_ix)
    ixes = []
    for t in range(n):
        output, h,c = rnn(x, h,c)
        ix = tensor_to_ix(output)
        ixes.append(ix)
        x = ix_to_tensor(ix)
        
    return ixes

# %%
n, p = 0, 0

while True:
    if p+seq_length+1 >= len(data) or n == 0: 
        h,c = rnn.init_hidden()
        p = 0 # go from start of data
        
    inputs = [char_to_ix[ch] for ch in data[p:p+seq_length]]
    targets = [char_to_ix[ch] for ch in data[p+1:p+seq_length+1]]

    # sample from the model now and then
    if n % 1000 == 0:
        sample_ix = sample( inputs[0], 200)
        txt = ''.join(ix_to_char[ix] for ix in sample_ix)
        print ('----\n {} \n----'.format( txt) )

    # forward seq_length characters through the net and fetch gradient
    loss,h,c = train(inputs, targets, h,c) 
    h = Variable(h.data)
    c = Variable(c.data)
    
 
    if n % 1000 == 0:
        print( 'iter {}, loss: {}'.format(n, loss)) # print progress

    p += seq_length # move data pointer
    n += 1 # iteration counter
# Out:
# ----
#  cracrnocrnocrnocrnocrnocrnocrnocrnocrnocrnocrnocrnocrnocrnocrnocrnocrnocrnocrnocrnocrnocrnocrnocrnocrnocrnocrnocrnocrnocrnocrnocrnocrnocrnocrnocrnocrnocrnocrnocrnocrnocrnocrnocrnocrnocrnocrnocrnocrnoc
# ----
# iter 0, loss: 96.75086212158203
# ----
#  the the te te te te te te te te te te te te te te te te te te te te te te te te te te te te te te te te te te te te te te te te te te te te te te te te te te te te te te te te te te te te te te te te
# ----
# iter 1000, loss: 51.944923400878906
# ----
#  mate seste taon ingersical dist anterstion indersting, indersting, inde testrantion indersting, indersting, onder tion from the the restempution ingersical diste the the the the the the the the the th
# ----
# iter 2000, loss: 31.97032928466797
# ----
#  gerical discipline from the real deal with ditho the reann uner destor the hear the thor the heron the he an the real to the he theor thal inger inal discal ingericaio from image dath the theor thath
# ----
# iter 3000, loss: 22.464698791503906
# ----
#  gerical orstimation, mometers understanding and understanding in the con the unal the from the real the tarn that incerine, or computer vision is anderstandersican or computer vision is anderstandersi
# ----
# iter 4000, loss: 15.357990264892578
# ----
#  mate vision iscal antificis ingering, ionce semat of the eer and understanding ditalicin, of the world that can interface with other thought processes and elicit appropriate action. This image data ca
# ----
# iter 5000, loss: 8.6605224609375
# ----
#   the extraction of high-dimensional data from the real world in order to produce numerical or symbolic information from images. The image data can take many forms, such as video sequermesion, andimeti
# ----
# iter 6000, loss: 7.374317646026611
# ----
#  geriag, analyzing and understanding digital images, and in general, deal with the extraction of high-dimensional data from the real world in order to produce numerical or symbolic information from ima
# ----
# iter 7000, loss: 3.116032123565674
# ----
#  hogluth the that deal with the the the thecting, vial discin tiscineering, olecision be mode to prodes the tracs of momputer vision seeks to apply its theories and models for acquiring, processing, om
# ----
# iter 8000, loss: 7.1409149169921875
# ----
#  mate vision iscal ant from image data using models constructed with the aid of geometry, physics, statistics, and learning theory.[8]
# As a scientific discipline, computer vision seeks to apply its the
# ----
# iter 9000, loss: 0.29131752252578735
# ----
#  hith the ar thuul data uing t onger intloderstion, inder tod the extraction of high-dimensional data from the real world in order to produces, and in genernal dita tarn if hugensirtas inger the dithat
# ----
# iter 10000, loss: 1.4964680671691895
# ----
#  ng, object recognition, object pose estimation, learning, indexing, motion estimation, and in general, deal with the extraction of high-dimensional data from the real world in order to produce numeric
# ----
# iter 11000, loss: 0.36814936995506287
# ----
#  ane mate taskent formstippinaly from dimal discinal data can take many forms, such as video sequences, views from multiple cameras, or multi-dimensional data from a medical scanner. As a technological
# ----
# iter 12000, loss: 0.20990145206451416
# ----
#   om the reals with how computers can be made to gain high-level understanding from digital images or videos. From the perspective of engineering, it seeks to automate tasks that the human visual syste
# ----
# iter 13000, loss: 0.36174479126930237
# ----
#  ng, indexing, motion estimation, and information, e.g., in the forms of decisions.[4][5][6][7] Understanding in this context means the transformation of visual images (the input of the retina) into de
# ----
# iter 14000, loss: 0.21197666227817535
# ----
#  ng, object raceos ohe enwing, videos. This image data cannt metron, object decens or mulel images. The iean, videos. From the cens vestrvcal systhe tran, vision is concerned with the theory behind art
# ----
# iter 15000, loss: 6.395907878875732
# ----
#  derstans in thion erntimation, learning, indexing, motion estimation, and leal with the theory behind artificial systems that extract information from images. The image data can take many forms, such
# ----
# iter 16000, loss: 0.13603022694587708
# ----
#  ormation of visual images (the input of the retina) into descriptions of the world that can interface with other thought processes and elicit appropriate action. This image understanding can be seen a
# ----
# iter 17000, loss: 0.17365263402462006
# ----
#  gerisciplinary field that deals with how computers can be made to gain high-level understanding from digital images or videos. From the perspective of engineering, it seeks to automate tasks that the
# ----
# iter 18000, loss: 0.11517934501171112
# ----
#  ormation of visual images (the input of the retina) into descriptions of the world that can interface with other thought processes and elicit appropriate action. This image understanding can be seen a
# ----
# iter 19000, loss: 0.5873178243637085
# ----
#  theory behind artificial systems that extract information from images. The image data can take many forms, such as video sequences, views from multiple cameras, or multi-dimensional data from a medica
# ----
# iter 20000, loss: 0.22239363193511963
# ----
#  ng, object onery gien rescimpition, object posere can bo made to gain high-level understanding from digital images or videos. From the perspective of engineering, it seeks to automate tasks that the h
# ----
# iter 21000, loss: 0.06754638254642487
# ----
#   om the woras the rise thetry thewing mat om the rean ans forsciscipn, estimation, and in general, deal with the extraction of high-dimensional data from the real world in order to produce numerical o
# ----
# iter 22000, loss: 0.24646764993667603
# ----
#  ng, object an, con the with otaeny forms image understanding can be seen as the disentangling of symbolic information from image data using models constructed with the aid of geometry, physics, statis
# ----
# iter 23000, loss: 0.08828452974557877
# ----
#  [1][7] Understanding in this context means the transformation of visual images (the input of the retina) into descriptions of the world that can interface with other thought processes and elicit appro
# ----
# iter 24000, loss: 0.06025579199194908
# ----
#  ical scanner. As a technological discipline, computer vision seeks to apply its theories and models for the construction of computer vision systems.
# Sub-domains of computer vision include scene recons
# ----
# iter 25000, loss: 0.06793485581874847
# ----
#  1][6][7] Understanding in this context means the transformation of visual images (the input of the retina) into descriptions of the world that can interface with other thought processes and elicit app
# ----
# iter 26000, loss: 0.03487743064761162
# ----
#  roplise nata usernation of computer vision systems.
# Sub-domains of computer vision include scene reconstruction, event detection, video tracking, object recognition, object pose estimation, learning,
# ----
# iter 27000, loss: 0.05971729755401611
# ----
#  ring, prodescing, analyzing and understanding digital images, and in general, deal with the extraction of high-dimensional data from the real world in order to produce numerical or symbolic informatio
# ----
# iter 28000, loss: 0.1430172324180603
# ----
#  ring, processing, analyzing and understanding digital images, and in general, deal with the extraction of high-dimensional data from the real world in order to produce numerical or symbolic informatio
# ----
# iter 29000, loss: 0.07567404210567474
# ----
#  me mane tasks that the human visual system can do.[1][2][3]
# Computer vision is concerned with the theory behind artificial systems that extract information from images. The image data can take many fo
# ----
# iter 30000, loss: 1.2814500331878662
# ----
#  omputer vision is an interdisciplinary field that deals with how computers can be made to gainalyzing and understanding digital images, and in general, deal with the uromption, objection, extraction o
# ----
# iter 31000, loss: 0.5831152200698853
# ----
#  theory.[8]
# As a scientific discipline, computer vision seeks to apply its theories and models for the construction of computer vision systems.
# Sub-domains of computer vision systems.
# Sub-domains of co
# ----
# iter 32000, loss: 0.07227925956249237
# ----
#  theory behind artificial systems that extract information from images. The image data can take many forms, such as video sequences, views from multiple cameras, or multi-dimensional data from a medica
# ----
# iter 33000, loss: 0.08436299860477448
# ----
#  gerisciplinary fion extemation of high-dimensional data from the real world in order to produce numerical or symbolic information, e.g., in the forms of decisions.[4][5][6][7] Understanding in this co
# ----
# iter 34000, loss: 0.03042171709239483
# ----
#  geriac a discl itasksieng and entican in general, deal with the extraction of high-dimensional data from the real world in order to produce numerical or symbolic information, e.g., in the forms of dec
# ----
# iter 35000, loss: 0.031427521258592606
# ----
#  mate mane mane of computer visuon tasks include methods for acquiring, processing, analyzing and understanding digital images, and in general, deal with the extraction of high-dimensional data from th
# ----
# iter 36000, loss: 2.8319249153137207
# ----
#   of the world that can interface with other thought processes and elicit appropriate action. This image understanding can be seen as the disentangling of symbolic information from image data using mod
# ----
# iter 37000, loss: 0.09434015303850174
# ----
#  gerinal discipline, computer vision is concerned with the theory behind artificial systems that extract information from images. The image data can take many forms, such as video sequences, views from
# ----
# iter 38000, loss: 0.16488204896450043
# ----
#  theory behind artificial systems that extract information from images. The image data can take many forms, such as video sequences, views from multiple cameras, or multi-dimensional data from a medica
# ----
# iter 39000, loss: 0.04791378229856491
# ----
#  mate mate meterstaction, event detection, video tracking, object recognition, object pose estimation, learning, indexing, motion estimation, and forys.[8][6][7] Understanding in this context means the
# ----
# iter 40000, loss: 0.04502907395362854
# ----
#  theory thhon ufrr coltione mann forms, such as video sequences, views from multiple cameras, or multi-dimensional data from a medical scanner. As a technological discipline, computer vision seeks to a
# ----
# iter 41000, loss: 0.05941631644964218
# ----
#  ng, pometroction, event detection, video tracking, object recognition, object pose estimation, learning, indexing, motion estimation, and ingg. ind orncition, e.g. th omation, object pose estimation,
# ----
# iter 42000, loss: 0.04769986867904663
# ----
#  ane can. This image understanding can be seen as the disentangling of symbolic information, e.g., in the forms of decisions.[4][5][6][7] Understanding in this context means the transformation of visua
# ----
# iter 43000, loss: 0.20943863689899445
# ----
#   include scene reconstruction, event detection, video tracking, object recognition, object pose estimation, learning, indexing, motion estimation, and learning theory.[8]
# As a scientific discipline, c
# ----
# iter 44000, loss: 0.023507550358772278
# ----
#  ng, motition estimation, and understanding digital images, and in general, deal with the extraction of high-dimensional data from the real world in order to produce numerical or symbolic information,
# ----
# iter 45000, loss: 0.01126867812126875
# ----
#  ng, motition estimation, and understanding digital images, and in general, deal with the extraction of high-dimensional data from the real world in order to produce numerical or symbolic information,
# ----
# iter 46000, loss: 0.020057927817106247
# ----
#  discinal systems that extract information from images. The image data can take many forms, such as video sequences, views from multiple cameras, or multi-dimensional data from a medical scanner. As a
# ----
# iter 47000, loss: 0.11835570633411407
# ----
#  ormaticn, erand fors, dith the theory behind artificial systems that extract information from images. The image data can take many forms, such as video sequences, views from multiple cameras, or multi
# ----
# iter 48000, loss: 0.03585699200630188
# ----
#  geras in grone conce tad inal ung, ingestimation, and in general, deal with the extraction of high-dimensional data from the real world in order to produce numerical or symbolic information, e.g., in
# ----
# iter 49000, loss: 0.03605182096362114
# ----
#  orms the hine eat dat ditiotiof aid in gene tametrmation, enthodecs and in ernte secmation, eetr te geons estamating of symbolic information, e.g., in the forms of decisions.[4][5][6][7] Understanding
# ----
# iter 50000, loss: 0.021799098700284958
# ----
#  theory thah that deals with how computers can be made to gain high-level understanding from digital images or videos. From the perspective of engineering, it seeks to automate tasks that the human vis
# ----
# iter 51000, loss: 0.09602437913417816
# ----
#  ng, mode construction, event detection, video tracking, object recognition, object pose estimation, learning, indexing, motion estimation, and unarng, vitho theory behind artificial systems that extra
# ----
# iter 52000, loss: 0.03182491287589073
# ----
#   and in general, deal with the extraction of high-dimensional data from the real world in order to produce numerical or symbolic information, e.g., in the forms of decisions.[4][5][6][7] Understanding
# ----
# iter 53000, loss: 0.01859884336590767
# ----
#  ng, moncl inarnical systems.
# Sub-domains of computer vision include scene reconstruction, event detection, video tracking, object recognition, object pose estimation, learning, indexing, motion estima
# ----
# iter 54000, loss: 0.01413023192435503
# ----
#   The image data naing rode sequences, views from multiple cameras, or multi-dimensional data from a medical scanner. As a technological discipline, computer vision is concerned with the theory behind
# ----
# iter 55000, loss: 0.06400126963853836
# ----
#  iscipline, computer vision is concerned with the theory behind artificial systems that extract information from images. The image data can take many forms, such as video sequences, views from multiple
# ----
# iter 56000, loss: 0.02717178501188755
# ----
#  1][6][7] Understanding in this context means the transformation of visual images (the input of the retina) into descriptions of the world that can interface with other thought processes and elicit app
# ----
# iter 57000, loss: 0.0101244505494833
# ----
#  ropli ian, etheristiongis and understanding digital images, and in general, deal with the extraction of high-dimensional data from the real world in order to produce numerical or symbolic information,
# ----
# iter 58000, loss: 0.017205873504281044
# ----
#   made to gain high-level understanding from digital images or videos. From the perspective of engineering, it seeks to automate tasks that the human visual system can do.[1][2][3]
# Computer vision task
# ----
# iter 59000, loss: 0.07172144204378128
# ----
#   made to gain high-level understanding from digital images or videos. From the perspective of engineering, it seeks to automate tasks that the human visual system can do.[1][2][3]
# Computer vision task
# ----
# iter 60000, loss: 0.027284279465675354
# ----
#  ce mane extraction, e.g., in the forms of decisions.[4][5][6][7] Understanding in this context means the transformation of visual images (the input of the retina) into descriptions of the world that c
# ----
# iter 61000, loss: 2.2870097160339355
# ----
#  omputer vision is an interdisciplinary field that deals with how computers can be made to gain high-level understanding from digital images or videos. From the perspective of engineering, it seeks to
# ----
# iter 62000, loss: 0.08859971165657043
# ----
#  the hugns utht htarsticngof in or englude teome the human visual system can do.[1][2][3]
# Computer vision tasks include methods for acquiring, processing, analyzing and understanding digital images, an
# ----
# iter 63000, loss: 0.053335078060626984
# ----
#  theory behind artificial systems that extract information from images. The image data can take many forms, such as video sequences, views from multiple cameras, or multi-dimensional data from a medica
# ----
# iter 64000, loss: 0.04077852517366409
# ----
#  geran, dital images, and in general, deal with the extraction of high-dimensional data from the real world in order to produce numerical or symbolic information, e.g., in the forms of decisions.[4][5]
# ----
# iter 65000, loss: 0.0601353757083416
# ----
#  g, monge understanding digital images, and in general, deal with the extraction of high-dimensional data from the real world in order to produce numerical or symbolic information, e.g., in the forms o
# ----
# iter 66000, loss: 0.026829224079847336
# ----
#  m the reans for the cogntific discipline, computer vision seeks to apply its theories and models for the construction of computer vision systems.
# Sub-domains of computer vision seeks to apply its theo
# ----
# iter 67000, loss: 1.307314157485962
# ----
#   include secensican trom the rean vodeos. This image understanding can be seen as the disentangling of symbolic information from image data using models constructed with the aid of geometry, physics,
# ----
# iter 68000, loss: 0.45809370279312134
# ----
#  g, dige trory formction tasks include methods for acquiring, processing, analyzing and understanding digital images, and in general, deal with the extraction of high-dimensional data from the real wor
# ----
# iter 69000, loss: 1.5367947816848755
# ----
#  theory behind artificial systems that extract information from images. The image data can take many forms, such as video sequences, views from multiple cameras, or multi-dimensional data from a medica
# ----
# iter 70000, loss: 0.043344736099243164
# ----
#  m the extract information from images. The image data can take many forms, such as video sequences, views from multiple cameras, or multi-dimensional data from a medical scanner. As a technological di
# ----
# iter 71000, loss: 0.005079595372080803
# ----
#  theory behind artificial systems that extract information from images. The image data can take many forms, such as video sequences, views from multiple cameras, or multi-dimensional data from a medica
# ----
# iter 72000, loss: 0.05154901370406151
# ----
#  ng, include scene reconstruction, event detection, video tracking, object recognition, object pose estimation, learning, indexing, motion estimation, and understanding digital images, and in general,
# ----
# iter 73000, loss: 0.034818895161151886
# ----
#  ane cangrint, ditas. From the perspective of engineering, it seeks to automate tasks that the human visual system can do.[1][2][3]
# Computer vision is an interdisciplinary field that deals with how com
# ----
# iter 74000, loss: 0.0639638602733612
# ----
#   include scon extiscin of computer vision seeks to apply its theories and models for the construction of computer vision systems.
# Sub-domains of computer vision include scene reconstruction, event det
# ----
# iter 75000, loss: 0.019239453598856926
# ----
#  ng, poneestanding in this context means the transformation of visual images (the input of the retina) into descriptions of the world that can interface with other thought processes and elicit appropri
# ----
# iter 76000, loss: 0.016820643097162247
# ----
#  ng, processes and elicit appropriate action. This image understanding can be seen as the disentangling of symbolic information from image data using models constructed with the aid of geometry, physic
# ----
# iter 77000, loss: 0.08728905022144318
# ----
#  level understanding from digital images or videos. From the perspective of engineering, it seeks to automate tasks that the human visual system can do.[1][2][3]
# Computer vision tasks include methods f
# ----
# iter 78000, loss: 0.016050659120082855
# ----
#  ormation from images. The image data can take many forms, such as video sequences, views from multiple cameras, or multi-dimensional data from a medical scanner. As a technological discipline, compute
# ----
# iter 79000, loss: 0.04469713941216469
# ----
#  g, motion estimation, and in general, deal with the extraction of high-dimensional data from the real world in order to produce numerical or symbolic information, e.g., in the forms of decisions.[4][5
# ----
# iter 80000, loss: 0.06469651311635971
# ----
#  ormation from images. The image data can take many forms, such as video sequences, views from multiple cameras, or multi-dimensional data from a medical scanner. As a technological discipline, compute
# ----
# iter 81000, loss: 0.01590588130056858
# ----
#  theory behind artificial systems that extract information from images. The image data can take many forms, such as video sequences, views from multiple cameras, or multi-dimensional data from a medica
# ----
# iter 82000, loss: 0.03578517958521843
# ----
#  ng, porotistics, and learning theory.[8]
# As a scientific discipline, computer vision is concerned with the theory behind artificial systems that extract information from images. The image data can tak
# ----
# iter 83000, loss: 0.014179378747940063
# ----
#   concurnce cunderstanding digital images, video tracking, object recognition, object pose estimation, and in general, deal with the extraction tasks include secons, vie catical systems.
# Sub-disice tad
# ----
# iter 84000, loss: 2.6000730991363525
# ----
#  ng, inde seans con thisicon include scene reconstruction, event detection, video tracking, object recognition, object pose estimation, learning, indexing, motion estimation, and in general, deal with
# ----
# iter 85000, loss: 0.03234196454286575
# ----
#   The seenn cont ration, object recognition, object pose estimation, learning, indexing, motion estimation, and in general, deal with the extraction of high-dimensional data from the real world in orde
# ----
# iter 86000, loss: 0.024297339841723442
# ----
#  iscipline, computer vision systems.
# Sub-domains of computer vision systems.
# Sub-domains of computer vision systems.
# Sub-domains of computer vision systems.
# Sub-domains of computer vision systems.
# Sub-
# ----
# iter 87000, loss: 0.0127562265843153
# ----
#  1][2][3]
# Computer vision is an interdisciplinary field that deals with how computers can be made to gain high-level understanding from digital images or videos. From the perspective of engineering, it
# ----
# iter 88000, loss: 0.6536217331886292
# ----
#  ropriate action. This image understanding can be seen as the disentangling of symbolic information from image data using models constructed with the aid of geometry, physics, statistics, and learning
# ----
# iter 89000, loss: 0.011256777681410313
# ----
#   made to gain high-level understanding from digital images or videos. From the perspective of engineering, it seeks to automate tasks that the human visual system can do.[1][2][3]
# Computer vision task
# ----
# iter 90000, loss: 0.012787969782948494
# ----
#   made to gain high-level understanding from digital images or videos. From the perspective of engineering, it seeks to automate taoks estamstor ical in engine, coplutersesestan ing rome thehry.[8]
# As
# ----
# iter 91000, loss: 0.03453904762864113
# ----
#  ce mate hiscol interscong in ernd inal dag digital images or videos. From the perspective of engineering, it seeks to automate tasks that the human visual system can do.[1][2][3]
# Computer vision tasks
# ----
# iter 92000, loss: 0.2368173450231552
# ----
#  omputer vision is an interdisciplinary field that deals with how computers can be made to gain high-level understanding from digital images or videos. From the perspective of engineering, it seeks to
# ----
# iter 93000, loss: 0.020930372178554535
# ----
#  theory behind artificial systems that extract information from images. The image data can take many forms, such as video sequences, views from multiple cameras, or multi-dimensional data from a medica
# ----
# iter 94000, loss: 0.05106865242123604
# ----
#  theory behind artificial systems that extract information from images. The image data can take many forms, such as video sequences, views from multiple cameras, or multi-dimensional data from a medica
# ----
# iter 95000, loss: 0.024746252223849297
# ----
#  geruction of the real world in order to produce numerical or symbolic information, e.g., in the forms of decisions.[4][5][6][7] Understanding in this context means the transformation of visual images
# ----
# iter 96000, loss: 0.022547626867890358
# ----
#  germation from image data using models constructed with the aid of geometry, physics, statistics, and learning theory.[8]
# As a scientific discipline, computer vision systems.
# Sub-domains of computer v
# ----
# iter 97000, loss: 0.011017466895282269
# ----
#  mate discipline, computer vision systems.
# Sub-domains of computer vision systems.
# Sub-domains of computer vision systems.
# Sub-domains of computer vision systems.
# Sub-domains of computer vision systems
# ----
# iter 98000, loss: 8.192283630371094
# ----
#   incerned the transformation of visual images (the input of the retina) into descriptions of the world that can interface with other thought processes and elicit appropriate action. This image underst
# ----
# iter 99000, loss: 0.08150894939899445
# ----
#  g, motion tasks that the human visual system can do.[1][2][3]
# Computer vision tasks include methods for acquiring, processing, analyzing and understanding digital images, and in general, deal with the
# ----
# iter 100000, loss: 1.873602032661438
# ----
#  theory thehd with other thought processes and elicit appropriate action. This image understanding can be seen as the disentangling of symbolic information from image data using models constructed with
# ----
# iter 101000, loss: 0.037718579173088074
# ----
#  mate tasy beal with other thought processes and elicit appropriate action. This image understanding can be seen as the disentangling of symbolic information from image data using models constructed wi
# ----
# iter 102000, loss: 0.004790342412889004
# ----
#  theory behind artificial systems that extract information from images. The image data can take many forms, such as video sequences, views from multiple cameras, or multi-dimensional data from a medica
# ----
# iter 103000, loss: 0.008679138496518135
# ----
#  ng, indexing, motion estimation, and inagyzing and understanding digital images, and in general, deal with the extraction of high-dimensional data from the real world in order to produce numerical or
# ----
# iter 104000, loss: 0.03317734971642494
# ----
#  ane cans for the construction of computer vision systems.
# Sub-domains of computer vision include scene reconstruction, event detection, video tracking, object recognition, object pose estimation, lear
# ----
# iter 105000, loss: 0.01913955807685852
