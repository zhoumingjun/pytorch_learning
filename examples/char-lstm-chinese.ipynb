# %% [markdown]
# # This is the pytorch version of karpathy's charnn
#     reference: https://gist.github.com/raphaelbastide/11ae4bb5e454e5c5239f

# %%
import torch
from torch import nn
from torch.autograd import Variable
import torch.optim as optim

# %%
# data I/O
data = open('input1.txt', 'r', encoding='utf-8').read() # should be simple plain text file
chars = list(set(data))
data_size, vocab_size = len(data), len(chars)
print ('data has {} characters, {} unique.'.format( data_size, vocab_size))
char_to_ix = { ch:i for i,ch in enumerate(chars) }
ix_to_char = { i:ch for i,ch in enumerate(chars) }
# Out:
# data has 1947 characters, 521 unique.

# %%
# hyperparameters
token_size = vocab_size
input_size = 10
hidden_size = 50 # size of hidden layer of neurons
seq_length = 25 # number of steps to unroll the RNN for
learning_rate = 1e-3

# %%
# Utility functions
def ix_to_tensor(ix):
    return Variable(torch.LongTensor([[ix]])).cuda()


def tensor_to_ix(t):
    v,i = torch.max(t,1)
    return i.data[0][0]

# %%
# nn module
class CharRNN(nn.Module):
 
    def __init__(self, token_size, input_size, hidden_size):
        super(CharRNN, self).__init__()
        self.token_size = token_size
        self.input_size = input_size
        self.hidden_size = hidden_size

        
        self.encoder = nn.Embedding(token_size, input_size)
        self.rnn = nn.LSTMCell(input_size, hidden_size)
        self.linear = nn.Linear(hidden_size, token_size)
        
    def forward(self, input, h,c):
        emb = self.encoder(input).view(1, -1)
        h,c = self.rnn(emb, (h,c))
        output = self.linear(h)
        return output, h,c

    def init_hidden(self):
        return Variable(torch.FloatTensor(1, self.hidden_size).zero_()).cuda() ,Variable(torch.FloatTensor(1, self.hidden_size).zero_().cuda())

# %%
rnn = CharRNN(token_size, input_size, hidden_size).cuda()
criterion=nn.CrossEntropyLoss()
optimizer = optim.Adam(rnn.parameters(), lr=learning_rate)

def train(inputs, targets, h,c):
    optimizer.zero_grad()

    loss = 0
    for i in range(len(inputs)):
        input = ix_to_tensor(inputs[i])
        target = Variable(torch.LongTensor([targets[i]])).cuda()

        output, h,c = rnn(input, h,c)
        loss += criterion(output, target)
    
    loss.backward()
    optimizer.step()

    return loss.data[0] , h,c

def sample(seed_ix, n):
    h,c = rnn.init_hidden()

    x = ix_to_tensor(seed_ix)
    ixes = []
    for t in range(n):
        output, h,c = rnn(x, h,c)
        ix = tensor_to_ix(output)
        ixes.append(ix)
        x = ix_to_tensor(ix)
        
    return ixes

# %%
n, p = 0, 0

while True:
    if p+seq_length+1 >= len(data) or n == 0: 
        h,c = rnn.init_hidden()
        p = 0 # go from start of data
        
    inputs = [char_to_ix[ch] for ch in data[p:p+seq_length]]
    targets = [char_to_ix[ch] for ch in data[p+1:p+seq_length+1]]

    # sample from the model now and then
    if n % 1000 == 0:
        sample_ix = sample( inputs[0], 200)
        txt = ''.join(ix_to_char[ix] for ix in sample_ix)
        print ('----\n {} \n----'.format( txt) )

    # forward seq_length characters through the net and fetch gradient
    loss,h,c = train(inputs, targets, h,c) 
    h = Variable(h.data).cuda()
    c = Variable(c.data).cuda()
    
 
    if n % 1000 == 0:
        print( 'iter {}, loss: {}'.format(n, loss)) # print progress

    p += seq_length # move data pointer
    n += 1 # iteration counter
# Out:
# ----
#  什颜，分，，密脱脱从脱从脱从脱从脱从脱从脱从脱从脱从脱从脱从脱从脱从脱从脱从脱从脱从脱从脱从脱从脱从脱从脱从脱从脱从脱从脱从脱从脱从脱从脱从脱从脱从脱从脱从脱从脱从脱从脱从脱从脱从脱从脱从脱从脱从脱从脱从脱从脱从脱从脱从脱从脱从脱从脱从脱从脱从脱从脱从脱从脱从脱从脱从脱从脱从脱从脱从脱从脱从脱从脱从脱从脱从脱从脱从脱从脱从脱从脱从脱从脱从脱从脱从脱从脱从脱从脱从脱从脱从脱从脱从脱从脱从脱从脱从脱从
# ----
# iter 0, loss: 155.58978271484375
# ----
#  上的，自己己，了的，自己，自己的，自己的，自己的，自己的，自己的，自己的，自己的，自己的，自己的，自己的，自己的，自己的，自己的，自己的，自己的，自己的，自己的，自己的，自己的，自己的，自己的，自己的，自己的，自己的，自己的，自己的，自己的，自己的，自己的，自己的，自己的，自己的，自己的，自己的，自己的，自己的，自己的，自己的，自己的，自己的，自己的，自己的，自己的，自己的，自己的，自己的，自己的
# ----
# iter 1000, loss: 117.32456970214844
# ----
#  来立慢慢了，自己己受伤的么，自己己此的伤的，用了的树枝，用手自己了的一个叶堆，用手手了出的瓶子子
# 是韩立这个，用手手了出出，自己受伤立慢在么大的树叶堆，用手手自己的一伤的树枝，用手手自己己的伤的，用了，自己己此，韩立在么大的树叶堆，用手手自己的一伤的树枝，用手手自己己的伤的，用了，自己己此，韩立在么大的树叶堆，用手手自己的一伤的树枝，用手手自己己的伤的，用了，自己己此，韩立在么大的树叶堆，用手手自
# ----
# iter 2000, loss: 91.8636474609375
# ----
#  了铁。
# 韩立慢慢了枝个枝个，用双手手了瓶子，从有些。
# 韩立现在了望子个，用手了出，用手自己受此伤的，用子
# 韩立现在了子个小小瓶子，瓶子是拿瓶子到这个边小瓶子，韩立现在苦难，用手手了出瓶子放子，用手手出出瓶子放子属瓶子表瓶子表面手手了出出来，用手在上胡乱指了什么。
# 韩立倒吸了，用不有些什么，自己也能也大的树枝，这个月“象甲功”的，自己也道在瞅什么重要，用手了，自己受此伤的，用子
# 韩立现在了子个小小瓶
# ----
# iter 3000, loss: 64.01300811767578
# ----
#  指能寄寄嘴的么脚门后门的树枝，这是一个月作，韩立慢在了望路着座山峰，刚的，用有什么重要的弟叶堆，用手了一下，抓是一起，用手在上胡上的，让暗着，用上手嘴了剧。
# 韩立躬，这个，用双手了，住了，一起脚。
# 韩立倒吸了，自己也的脚拇指，自己也的脚脚指大的吹气的树叶堆里，一个起小瓶子产生了兴趣，这个，用双手了，住了一起，用手手了一下。
# 韩立仔作，韩立倒吸了一个小树枝，用双手手了住了，一起往着的树叶堆，一个单调
# ----
# iter 4000, loss: 51.18585968017578
# ----
#  后
# 韩立以为在苦难，用手中的，用手中的、指，能根本本的颜出出来，用中的树叶堆里。
# 韩立仔细打量的，自己的脚拇指，随后
# 他过就好了什么变的弟痛的树叶堆里。
# “估计的小路多不准点的往良后门后。
# 韩立以为了两是一个小瓷瓶瓶盖上，瓶手手瓶盖上住了，感觉不出一此大的疼子测试时了，更别说留起，从不的树叶堆里的一块非常硬的石彩。
# 因此，韩立躬起身子，用双手手了一股钻。
# 韩立仔细打了甲功，一个小小路，不时受伤的脚
# ----
# iter 5000, loss: 31.28759765625
# ----
#  这个月作“象甲功”的，自己也能也根本就就不有什么好好好有什么好好的？难这个什么变化。
# 这，这个月头甲功”的，能消了伤的，在给新着上，还不要伤的，一起这起，一边身子蹲身来，沿着的一起小路着落的疼痛的右掉着的的吹祸首。
# 四周地上散落的的树叶堆里四的扒拉的右掉练有几层皮。
# “估计张铁，现在恐怕已经有些后悔了吧？这“象甲功”的霸道之处，远远超出自己也看不有些什么，从脚拇指大的吹气；一下面把把子倒是很少少的
# ----
# iter 6000, loss: 30.69821548461914
# ----
#  自己受伤的罪常杂杂常器格斗的训。
# 每当韩立看大对了吧？。
# “估计张铁，现在恐怕已经有些后悔了吧？这“象甲功”的霸道之处，远远超出他们一下子起，用双手抱住脖，好子
# 里是会这套口诀了两不出的脚撞情脚上，让张铁，心就那里着上，还不了些，不不学好好的功些口口脚指却进行实刀兵器来的撞击，舞上，韩立就为了防止被原是一边路在恐怕已经有些发了，用双手死死的按住了，一面。
# 韩立这起，这个着，用手在上点伤的，自己也此
# ----
# iter 7000, loss: 15.438384056091309
# ----
#  日之所以每天按重准进行兵器格斗的训练。
# 每当韩立看到其他同门聚到一起，进行实刀实枪训练的情形，心里就有些不是滋味，自己也能也根本就过的两是想要，从的事情要做的树叶堆里使劲的扒拉了几下。
# 咦！一个拳头大小的东西被树枝挑了出来。
# 韩立仔细打量了一下，这个造成自己光荣负伤的元凶，只是区了防止被他要神的撞，用的会后不是一下，把能韩立倒吸了树枝，往四周厚厚的树叶堆里使劲的扒拉了几下。
# 咦！一个拳头大小的东西
# ----
# iter 8000, loss: 9.970108032226562
# ----
#  交大夫情。
# 他！学其他不学好好有的什么重。
# 这个月“象甲功”的张铁，也变的皮糙肉厚更能挨打，力气也比以前大了许多。
# 可是若不是被墨大夫收入门下，自己可能也根本就过不了两个月前的记名弟子测试，更别说留在山上，能寄回家那么多钱
# 不能学其它的，自己也好这些想着，自己也能也根本就过的两是口口诀没后果的一起口凉气，一起向气劲的，从气了一日千的第一层想要，顶端出有的什么重。
# 现在并没有什么重要的事情要做，这几
# ----
# iter 9000, loss: 7.433189392089844
# ----
#  瓶子表面沾满了泥土，完全变成了土灰色，看不出一点本来的色彩。
# 原本韩立以为这是一个小瓷瓶，但是拿到手中却发现份量的疼痛一下，这个造成着，上套着，脚上套着，偶气翼翼的站脚后跟，随又不是一下附近的，一种在种上套乎了秋末，他脸色进。
# 这些声音的真不是是很少见到了后。
# 是金属制成了吧？难里里，自己能替伤的找出自己受此伤的找出自己受此伤的小瓶子。
# 想是拿到了防止被他人进行老撞此光秃的小路，上套着，嘴那里跑的
# ----
# iter 10000, loss: 7.205479621887207
# ----
#  上套器的撞情。
# 韩立躬起身子，用双手抱住脚脖，一面下意识的，隔着自己脚上套着的布鞋，用嘴使劲的朝自己受伤的脚指大口的吹气；一面在心里暗暗担心，自己是否会伤的很严重，脚拇指是否会一下子淤血肿起来，从而影响到自己的日常行走。
# 过了老半天，韩立才缓过这股痛劲。他把自己的脖子抬起，目光往脚下附近的树叶堆里四处扫视，想要找出造成自己受此大罪的罪魁祸首。
# 四周地上散落的的树叶都是同一个单调色彩——枯黄色，自己
# ----
# iter 11000, loss: 1.6527538299560547
# ----
#  土漫不个交大心，自己脚触伤的，只入门。
# 这“象甲功”的霸道之处，远远超出他们这些小屁孩的想象。”韩立一边走，一边想着，还漫不经心的、用脚随意的踢着地上掉落的叶子和树枝。
# “等到再过些日子，两人就一起向墨大夫求求情，让张铁改练别的功夫，省的受此活罪。”韩立这样想着，他为自己能替朋友找出一条逃离现在苦难的出路，而感到有些振奋。
# 韩立抬头望了望路两旁的树木，这个时候，天时已经到了秋末，所有树木的树枝都光
# ----
# iter 12000, loss: 2.357118606567383
# ----
#
# 韩立抬头望了两是一边想到现在恐怕已经有些后悔了吧？这“象甲功”的霸道之处，远远超出他们这些小屁孩的想象。”韩立一边走，一边想着，还漫不经心的、用脚随意的踢着地上掉落的叶子和树枝。
# “等到再过些日子，两人就一起向墨大夫求求情，让张铁改练别的功夫，省的受此活罪。”韩立这样想着，他为自己能替朋友找出一条逃离现在苦难的出路，而感到有些振奋。
# 韩立抬头望了望路两旁的树木，这个时候，天时已经到了秋末，所有树
# ----
# iter 13000, loss: 1.5765876770019531
# ----
#  枝起入门劲。他把自己了些日之了瓶子，感觉不出造成有些精，韩立抬头不大，墨大夫就严吧！他武功，说是会妨碍他修行口诀有什么好的？到现在，自己也没看出它有什么用。别的一起入门的弟子都是身手越练越厉害，武功一日千里，自己却在原地不前，根本就看不出有什么变化。
# 就连只修炼了两个月“象甲功”的张铁，也变的皮糙肉厚更能挨打，力气也比以前大了许多。
# 可是若不是被墨大夫收入门下，自己可能也根本就过不了两个月前的记名
# ----
# iter 14000, loss: 1.4978446960449219
# ----
#  灰盖上，把拿的瓶盖的封口口了、意意意外得了找色，看自己也好想拿起真刀、真枪狠狠地耍上一把。可惜的是，不知道为什吗，从正式拜入墨大夫门下后，墨大夫就严禁他接触这些东西，并不准他再去其他教习那里学其他武功，说是会妨碍他修行口诀的进度。
# 因此，韩立也就只能干干的眼馋着，偶尔私下里，才能从几个交好的同门那里借过来几件兵刃，舞上几个来回，过把干瘾。
# 真是的，自己修炼的这套口诀有什么好的？到现在，自己也没看出
# ----
# iter 15000, loss: 1.0753183364868164
# ----
#  是会在并沾有着安安常铁改有什么要几个找出自己的此此伤。
# 韩立现在其大脚上又着的疼痛的厚厚的弟子测试几个来，小路上几时来，不过好好有什么变化。
# 就连只修炼了两个月“象甲功”的张铁，也变的皮糙肉厚更能挨打，力气也比以前大了许多。
# 可是若不是被墨大夫收入门下，自己可能也根本就过不了两个月前的记名弟子测试，更别说留在山上，能寄回家那么多钱
# 不能学其它的，就不学吧！
# 韩立一边在肚子里抱怨着，一边在自我安慰着
# ----
# iter 16000, loss: 0.7183218002319336
# ----
#  的走训掉盖使劲的踢到了树木的树枝挑了出来，紧接地上的的脚拇指里还着与的皮痛，还不经心此伤药，再好而感到自己脚上套的，用脚上还带着，自己脚上套套，好严不准他吧？这些东西个造成的出自己受此大的罪魁祸首。
# 坏了！自己想要寻找的目标。
# ，韩立皱了皱眉头，用手在地上胡乱抓摸了几下，抓起一根比较粗长的树枝，拄着、踮起脚后跟，小心翼翼的站了起来。
# 然后不甘心似的，用手中的树枝，往四周厚厚的树叶堆里使劲的扒拉了几
# ----
# iter 17000, loss: 0.47151851654052734
# ----
#  之以每会放到天，是会妨中都。
# 这些想为好自己却几个意外得来的小瓶子。
# 想是到了到那里，还是先回住处，去上点伤药，再好好琢磨琢磨这个意外得来的小瓶子。
# 想到这里，韩立为了防止被他人看见，也不嫌此物太脏，把瓶子倒的会妨碍他修行口诀的吹的树叶堆里使劲的扒拉了几下。
# 咦！一个拳头大小的东西被树枝挑了出来。
# 韩立仔细打量了一下，这个造成自己光荣负伤的元凶，是一个有着细长颈的圆瓶状物品，瓶子表面沾满了泥土，完
# ----
# iter 18000, loss: 0.4652528762817383
# ----
#  了如此。
# 韩立抬头望了一个头小瓶子产生了兴趣起，小路手受得了的，只是区的第痛变了。
# 这是百锻堂的教习师兄们，在给新入门的师弟进行兵器格斗的训练。
# 每当韩立看到其他同门聚到一起，进行实刀实枪训练的情形，心里就有些不是滋味，自己也好想拿起真刀、真枪狠狠地耍上一把。可惜的是，不知道为什吗，从正式拜入墨大夫门下后，墨大夫就严禁他接触这些东西，并不准他再去其他教习那里学其他武功，说是会妨碍他修行口诀的进度。
# ----
# iter 19000, loss: 0.3203086853027344
# ----
#  乱回一边想不气造成脚上，脚上，脚上点伤药，再好好琢磨琢磨这个意外得来的小瓶子。
# 想到这里，韩立为了防止被他人看见，也不嫌此物太脏，把瓶子倒的会妨碍他修行器诀了土几，一个拳头大的东西被树枝挑了出来。
# 韩立仔细打量了一下，这个造成自己光荣负伤的元凶，是一个有着细长颈的圆瓶状物品，瓶子表面沾满了泥土，完全变成了土灰色，看不出一点本来的色彩。
# 原本韩立以为这是一个小瓷瓶，但是拿到手中却发现份量不对，沉甸甸
# ----
# iter 20000, loss: 0.2600898742675781
# ----
#  是会在并沾有着安入入门练心地上多能替套着，只气这个月起彩——枯黄色，自己根本就无法从那些乱七八糟的树叶堆中找出自己想要寻找的目标。
# ，韩立皱了皱眉头，用手在地上胡乱抓摸了几下，抓起一根比较粗长的树枝，拄着、踮起脚后跟，小心翼翼的站了起来。
# 然后不甘心似的，用手中的树枝，往四周厚厚的树叶堆里使劲的扒拉了几下。
# 咦！一个拳头大小的东西被树枝挑了出来。
# 韩立仔细打量了一下，这个造成自己光荣负伤的元凶，是
# ----
# iter 21000, loss: 0.18256664276123047
# ----
#  枝找出自己受此伤好的一个小巧的瓶盖紧紧紧瓶子倒的会妨碍他。
# 里不有什么，现在自己脚上套着，只气就自己是否会伤的很严重，脚拇指是否会一下子淤血肿起来，从而影响到自己的日常行走。
# 过了老半天，韩立才缓过这股痛劲。他把自己的脖子抬起，目光往脚下附近的树叶堆里四处扫视，想要找出造成自己受此大罪的罪魁祸首。
# 四周地上散落的的树叶都是同一个单调色彩——枯黄色，自己根本就无法从那些乱七八糟的树叶堆中找出自己想要
# ----
# iter 22000, loss: 0.1198577880859375
# ----
#  眉立慢慢地走手了出瓶子表面感地不会妨碍他修行口诀的进度。
# 因此，韩立也就只能干干的眼馋着，偶尔私下里，才能从几个交好不么把自己似外外下几，这个造成自己光荣负伤的元凶，是去不良拇指他是同门那里借过来几件兵刃，舞上几个来回，过把干瘾。
# 真是的，自己修炼的这套口诀有什么好到了到，用在上把进行练瓶地上，省会妨碍他修行口诀有树木的树枝时候光处的小路，嘴惯性的，向着模模糊糊可眺望见的赤水峰走去。
# 他现在并没有
# ----
# iter 23000, loss: 6.886602401733398
